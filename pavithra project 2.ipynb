# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data=pd.read_csv('c:\skin_cancer_dataset.csv')

# %%
data
# Out:
#       Age  Gender Skin_Type Sun_Exposure Family_History  Mole_Count Itchiness  \
# 0      69    Male    Type V     Moderate             No           6       Yes
# 1      32    Male    Type V     Moderate             No           3       Yes
# 2      89  Female   Type II          Low            Yes           4       Yes
# 3      78    Male   Type II         High            Yes           8       Yes
# 4      38  Female  Type III          Low             No           1        No
# ...   ...     ...       ...          ...            ...         ...       ...
# 9995   88  Female    Type V     Moderate            Yes           3        No
# 9996   43    Male    Type V         High            Yes           3       Yes
# 9997   63    Male    Type I          Low             No           6        No
# 9998   63  Female   Type IV          Low             No           6        No
# 9999   31    Male   Type II     Moderate             No           4        No
#
# ...

# %%
data.head()
# Out:
#    Age  Gender Skin_Type Sun_Exposure Family_History  Mole_Count Itchiness  \
# 0   69    Male    Type V     Moderate             No           6       Yes
# 1   32    Male    Type V     Moderate             No           3       Yes
# 2   89  Female   Type II          Low            Yes           4       Yes
# 3   78    Male   Type II         High            Yes           8       Yes
# 4   38  Female  Type III          Low             No           1        No
#
#   Bleeding Asymmetry Border_Irregularity Color_Variation  Diameter_mm  \
# 0       No       Yes                  No              No         6.90
# 1       No        No                 Yes              No         2.79
# 2      Yes       Yes                 Yes             Yes         5.41
# 3       No        No                  No              No         2.52
# 4      Yes       Yes                  No              No         4.09
#
#   Evolution  Skin_Cancer
# 0        No            0
# 1       Yes            0
# ...

# %%
data.tail()
# Out:
#       Age  Gender Skin_Type Sun_Exposure Family_History  Mole_Count Itchiness  \
# 9995   88  Female    Type V     Moderate            Yes           3        No
# 9996   43    Male    Type V         High            Yes           3       Yes
# 9997   63    Male    Type I          Low             No           6        No
# 9998   63  Female   Type IV          Low             No           6        No
# 9999   31    Male   Type II     Moderate             No           4        No
#
#      Bleeding Asymmetry Border_Irregularity Color_Variation  Diameter_mm  \
# 9995       No       Yes                 Yes             Yes         6.62
# 9996       No       Yes                 Yes             Yes         7.68
# 9997       No       Yes                  No              No         4.81
# 9998      Yes       Yes                  No             Yes         4.14
# 9999       No        No                  No              No         4.68
#
#      Evolution  Skin_Cancer
# 9995        No            1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
# Age                    10000 non-null int64
# Gender                 10000 non-null object
# Skin_Type              10000 non-null object
# Sun_Exposure           10000 non-null object
# Family_History         10000 non-null object
# Mole_Count             10000 non-null int64
# Itchiness              10000 non-null object
# Bleeding               10000 non-null object
# Asymmetry              10000 non-null object
# Border_Irregularity    10000 non-null object
# Color_Variation        10000 non-null object
# Diameter_mm            10000 non-null float64
# Evolution              10000 non-null object
# Skin_Cancer            10000 non-null int64
# dtypes: float64(1), int64(3), object(10)
# memory usage: 1.1+ MB

# %%
data.shape
# Out:
# (10000, 14)

# %%
data.describe()
# Out:
#                 Age    Mole_Count   Diameter_mm   Skin_Cancer
# count  10000.000000  10000.000000  10000.000000  10000.000000
# mean      53.539700      5.013900      4.991972      0.586000
# std       20.757324      2.237947      2.001363      0.492573
# min       18.000000      0.000000     -2.420000      0.000000
# 25%       36.000000      3.000000      3.657500      0.000000
# 50%       53.000000      5.000000      4.990000      1.000000
# 75%       72.000000      6.000000      6.340000      1.000000
# max       89.000000     14.000000     12.680000      1.000000

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Skin_Type', 'Sun_Exposure', 'Family_History',
#        'Mole_Count', 'Itchiness', 'Bleeding', 'Asymmetry',
#        'Border_Irregularity', 'Color_Variation', 'Diameter_mm', 'Evolution',
#        'Skin_Cancer'],
#       dtype='object')

# %%
data.loc[:,['Age','Gender','Skin_Type','Skin_Cancer']]
# Out:
#       Age  Gender Skin_Type  Skin_Cancer
# 0      69    Male    Type V            0
# 1      32    Male    Type V            0
# 2      89  Female   Type II            1
# 3      78    Male   Type II            0
# 4      38  Female  Type III            0
# ...   ...     ...       ...          ...
# 9995   88  Female    Type V            1
# 9996   43    Male    Type V            1
# 9997   63    Male    Type I            0
# 9998   63  Female   Type IV            0
# 9999   31    Male   Type II            0
#
# [10000 rows x 4 columns]

# %%
female = data[data['Gender'] == 'Female']

# %%
female
# Out:
#       Age  Gender Skin_Type Sun_Exposure Family_History  Mole_Count Itchiness  \
# 2      89  Female   Type II          Low            Yes           4       Yes
# 4      38  Female  Type III          Low             No           1        No
# 8      70  Female   Type VI     Moderate            Yes           3        No
# 12     19  Female   Type VI         High            Yes           4       Yes
# 14     77  Female    Type V     Moderate             No           7        No
# ...   ...     ...       ...          ...            ...         ...       ...
# 9986   34  Female  Type III          Low            Yes           3        No
# 9993   80  Female  Type III          Low             No           4        No
# 9994   63  Female   Type IV     Moderate             No           8       Yes
# 9995   88  Female    Type V     Moderate            Yes           3        No
# 9998   63  Female   Type IV          Low             No           6        No
#
# ...

# %%
female = data[data['Gender'] != 'Female']

# %%
female
# Out:
#       Age Gender Skin_Type Sun_Exposure Family_History  Mole_Count Itchiness  \
# 0      69   Male    Type V     Moderate             No           6       Yes
# 1      32   Male    Type V     Moderate             No           3       Yes
# 3      78   Male   Type II         High            Yes           8       Yes
# 5      41   Male   Type IV     Moderate             No           5       Yes
# 6      20   Male  Type III          Low             No           9        No
# ...   ...    ...       ...          ...            ...         ...       ...
# 9991   54   Male    Type V     Moderate            Yes           5        No
# 9992   36   Male   Type VI          Low            Yes           2        No
# 9996   43   Male    Type V         High            Yes           3       Yes
# 9997   63   Male    Type I          Low             No           6        No
# 9999   31   Male   Type II     Moderate             No           4        No
#
# ...

# %%
data['Mole_Count'].value_counts()
# Out:
# 4     1754
# 5     1721
# 6     1480
# 3     1392
# 7     1064
# 2      829
# 8      678
# 9      335
# 1      328
# 10     207
# 11      87
# 0       80
# 12      28
# 13      12
# 14       5
# Name: Mole_Count, dtype: int64

# %%
df = data[data['Family_History'] != 'No']

# %%
df
# Out:
#       Age  Gender Skin_Type Sun_Exposure Family_History  Mole_Count Itchiness  \
# 2      89  Female   Type II          Low            Yes           4       Yes
# 3      78    Male   Type II         High            Yes           8       Yes
# 8      70  Female   Type VI     Moderate            Yes           3        No
# 12     19  Female   Type VI         High            Yes           4       Yes
# 13     81    Male  Type III         High            Yes           9       Yes
# ...   ...     ...       ...          ...            ...         ...       ...
# 9989   63    Male    Type I     Moderate            Yes           4       Yes
# 9991   54    Male    Type V     Moderate            Yes           5        No
# 9992   36    Male   Type VI          Low            Yes           2        No
# 9995   88  Female    Type V     Moderate            Yes           3        No
# 9996   43    Male    Type V         High            Yes           3       Yes
#
# ...

# %%
df = data[data['Family_History'] == 'No']

# %%
df
# Out:
#       Age  Gender Skin_Type Sun_Exposure Family_History  Mole_Count Itchiness  \
# 0      69    Male    Type V     Moderate             No           6       Yes
# 1      32    Male    Type V     Moderate             No           3       Yes
# 4      38  Female  Type III          Low             No           1        No
# 5      41    Male   Type IV     Moderate             No           5       Yes
# 6      20    Male  Type III          Low             No           9        No
# ...   ...     ...       ...          ...            ...         ...       ...
# 9993   80  Female  Type III          Low             No           4        No
# 9994   63  Female   Type IV     Moderate             No           8       Yes
# 9997   63    Male    Type I          Low             No           6        No
# 9998   63  Female   Type IV          Low             No           6        No
# 9999   31    Male   Type II     Moderate             No           4        No
#
# ...

# %%
sns.barplot(x="Gender",y="Skin_Cancer",data=df)

# %%
sns.scatterplot(x="Age",y="Skin_Cancer",hue="Gender",data=df)
